# %%
import requests
from bs4 import BeautifulSoup as bs
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
response = requests.get('http://irm.cninfo.com.cn/')

# %%
content = response.content

# %%
soup = bs(content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <!-- 公用头部样式 -->
# <head>
# <meta charset="utf-8"/>
# <title>深交所互动易</title>
# <meta content="深圳证券信息有限公司" name="author"/>
# <meta content="webkit" name="renderer"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
# <meta content="深圳证券信息有限公司" name="apple-mobile-web-app-title"/>
# <meta content="深交所互动易,深交所互动平台,问董秘,上市公司,投资者关系,公司公告,机构调研信息" name="keywords"/>
# <meta content="互动易是由深交所官方推出，供投资者与上市公司直接沟通的平台，一站式公司资讯汇集，提供第一手的互动问答、投资者关系信息、公司声音等内容，整合了公司公告、股东信息、公司财务与融资等综合信息，帮助投资者更了解上市公司。" name="description"/>
# <link href="http://ircsstatic.cninfo.com.cn/ircs//assets/images/favicon.ico" rel="shortcut icon"/>
# <!-- 引入 element-ui 样式文件 -->
# <link href="http://ircsstatic.cninfo.com.cn/ircs//scripts/lib/element-ui/theme-chalk/index.css" rel="stylesheet"/>
# <link href="http://ircsstatic.cninfo.com.cn/ircs//scripts/lib/element-ui/theme-chalk/display.css" rel="stylesheet"/>
# <!-- 重置 css 样式 -->
# <link href="http://ircsstatic.cninfo.com.cn/ircs//styles/normalize.css" rel="stylesheet" type="text/css"/>
# <!-- 重置 iconfont 样式 -->
# <link href="http://ircsstatic.cninfo.com.cn/ircs//assets/iconfont/iconfont.css" rel="stylesheet" type="text/css"/>
# <!-- 引入 Swiper 样式文件 -->
# <link href="http://ircsstatic.cninfo.com.cn/ircs//scripts/lib/swiper/idangerous.swiper.min.css" rel="stylesheet" type="text/css"/>
# <link href="http://ircsstatic.cninfo.com.cn/ircs//scripts/lib/swiper/swiper-4.3.5.min.css" rel="stylesheet" type="text/css"/>
# <!-- 开发环境样式文件 -->
# <link href="http://ircsstatic.cninfo.com.cn/ircs//styles/common.css" rel="stylesheet" type="text/css"/>
# <link href="http://ircsstatic.cninfo.com.cn/ircs//styles/header.css" rel="stylesheet" type="text/css"/>
# <link href="http://ircsstatic.cninfo.com.cn/ircs//styles/index.css" rel="stylesheet" type="text/css"/>
# <script>
#         (function () {
#             window.TD_APPKEY= 'B90A3CC5854C4E0089A0FA909005A958';
#             window.TD_REQUEST_ASYN = true;
#             window.TD_REQUEST_URL = 'https://pub.szse.cn/g/w';
#             window.TD_REQUEST_CONF = '';
#             window.TD_AUTO_SEND_EVENT = true;
#             window.TD_LOOP_SENDDATA = false;
#             window.TD_ID_SAVE_IN_COOKIE = false;
#             window.TD_ID_POLICY = 'UUID';
#             window.TD_SDK_VERSION = 'WEB+APP+v5.0.20';
#             window.TD_AUTO_ACQUISITION_TITLE = true;
#             window.TD_PAGE_TIME_OPTIMIZE = false;
#             window.TD_EVENT_BY_ELEMENT = false;
#             window.TD_USER_CLICK_MAP = false;
#             window.TD_USER_CLICK_MAP_REQURL = 'https://pub.szse.cn/sdk/userClickMap';
#             window.TD_WEB_VIEW_FLAG_UA = '';
#             window.TD_AUTO_TRACK_URL = true;
#             window.TD_TRACK_FLAG = true;
#
#             window.IRCS_URL = 'http://ircsstatic.cninfo.com.cn/ircs/';
#             window.IRCS_API = 'http://irm.cninfo.com.cn/ircs';
#             window.IRCS_RES = 'http://resstatic.cninfo.com.cn/irm/';
#             window.ACE_CLOUDPOST_URL = 'https://list.cninfo.com.cn/public/cloudIntPost?key=';
#             window.API_SERVER = 'http://api.cninfo.com.cn'; //行情
#             window.API_CNINDEX = 'http://hq.cnindex.com.cn'; //深证行情
#             window.PRAISE_COUNT = '10';
#             window.USERCENTER_URL ='https://www.szse.cn/';
#             window.USERCENTER_LOGOUT_URL ='https://owssso.szse.cn/sso/logout';
#             window.SINA_APPKEY ='1823562971';
#             window.REPLY_URL = 'https://list.cninfo.com.cn'; //上市公司管理后台
#             window.QUIZE_SPEC_AREA = '香港|台湾|澳门|港台|港澳|港澳台';
#         })();
#     </script>
# <script src="http://ircsstatic.cninfo.com.cn/ircs//scripts/td-pc-website-sdk.js"></script>
# <script>
#         window.TRACKER_UID = '浏览用户';
#
#         //判断是否登录
#         var _isLogin = false;
#         var headerPageUserImgUrl = '';
#         var headerPageUserName = '';
#         function reloadIndex() {
#             location.reload();
#         }
#         var serverTime = ''
#     </script>
# <script src="http://ircsstatic.cninfo.com.cn/ircs//scripts/language-template.js"></script>
# <!-- 兼容 IE -->
# <script src="http://ircsstatic.cninfo.com.cn/ircs//scripts/lib/bluebird.min.js"></script>
# <link href="http://ircsstatic.cninfo.com.cn/ircs//scripts/lib/intro/introjs.css" rel="stylesheet" type="text/css"/>
# <!-- 业务逻辑代码 -->
# <script async="async" data-main="http://ircsstatic.cninfo.com.cn/ircs//scripts/pages/index-page" defer="" src="http://ircsstatic.cninfo.com.cn/ircs//scripts/lib/require.js"></script>
# <script>
#         //处理服务端渲染首页数据列表无图像
#         function handleNoCompanyHeads(_this) {
#             var $parent = _this.parentElement;
#             var $noImg = $parent.getElementsByClassName('index-no-img')[0];
#             _this.style.setProperty('display', 'none');
#             $noImg.style.display = 'inline-block';
#         }
#     </script>
# </head><body>
# <div class="irm-wrapper">
# <!--[if lte IE 8]>
#     <div class="browser-ver" id="browser-tips">
#         <div class="browser-ver-content">
#             由于您的浏览器版本过低，可能无法再本网站获得最佳体验。建议您将
#             <br/>
#             <span>
#             浏览器升级至 <a class=browserLinks href="http://windows.microsoft.com/zh-cn/internet-explorer/download-ie"
#                       target=_blank>IE9</a>
#             以上版本、或使用<a class=browserLinks href="http://www.google.cn/chrome/browser/" target=_blank>Chrome</a>
#             、<a class=browserLinks href="http://www.firefox.com.cn/" target=_blank>Firefox</a>
#             的最新版本
#         </span>
#         </div>
#     </div>
#     <![endif]-->
# <div class="header-wrapper" id="topApps" v-bind:class="dialogBug()" v-cloak="">
# <!-- pc 端头部 hidden-xs-only -->
# <div>
# <div class="container irm-header el-row hidden-xs-only" id="topApp">
# <div class="el-col-16">
# <a class="header-logo" href="http://irm.cninfo.com.cn/ircs/index">
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/irm-logo.png"/>
# <svg aria-hidden="true" class="icon xinban-icon" v-if="isEn" width="100%">
# <use xlink:href="#icon-icon_new-"></use>
# </svg>
# <svg aria-hidden="true" class="icon xinban-icon" v-else="" width="100%">
# <use xlink:href="#icon-ICON_xinban"></use>
# </svg>
# </a>
# <ul class="menu list-inline pull-left">
# <li class="menu-item"><a :class="{'active':isIndexPage == true}" href="http://irm.cninfo.com.cn/ircs/index">首页</a>
# </li>
# <li class="menu-item"><a href="http://wltp.cninfo.com.cn" target="_blank">投票</a>
# </li>
# <li class="menu-item ques-pos" id="step3">
# <span class="ask-question-btn"> 我要提问 </span>
# </li>
# </ul>
# <div class="header-input-box">
# <div class="header-input el-input">
# <div class="to-company-page" v-cloak="" v-show="showToCompany">公司主页&gt;
#                             </div>
# <input :maxlength="30" autocomplete="off" class="el-input__inner" id="header-search" placeholder="搜索" style="padding-right: 50px;" type="text" v-cloak="" v-model="searchTopInput"/>
# <span class="el-input__suffix searchSuffix" style="pointer-events: auto;">
# <span class="el-input__suffix-inner">
# <i class="iconfont icon-search el-input__icon"></i>
# </span>
# </span>
# <div class="header-autocomplete dsn">
# <div v-show="showHistorySearchBox">
# <div class="sub-title" v-if="historyList">历史搜索</div>
# <div v-if="historyList!=null">
# <div class="history-list" v-for="item in historyList">
# <div class="history-item" item.keyword="" item.orgid="" item.stockcode="" true="" v-if="item.type === 'stock'">
# <i class="el-icon-time"></i>
# <span class="name" v-if="textSize('15px','PingFang-SC-Medium',item.keyword).width&gt;= 290">{{item.keyword.substring(0,15)+'...'}}</span>
# <span class="name" v-else="">{{item.keyword}}</span>
# </div>
# <a :href="'http://irm.cninfo.com.cn/ircs/search?keyword='+ encodeURIComponent(item.keyword.replace(/%/g,'%25'))">
# <div class="history-item" false="" item.keyword="" v-if="item.type === 'key'">
# <i class="el-icon-time"></i>
# <span class="name" v-if="textSize('15px','PingFang-SC-Medium',item.keyword).width&gt;= 290">{{item.keyword.substring(0,15)+'...'}}</span>
# <span class="name" v-else="">{{item.keyword}}</span>
# </div>
# </a>
# </div>
# </div>
# <div class="sub-title">热门搜索</div>
# <div class="hot-list el-row">
# <div class="hot-item el-col-8" v-for="item in hotSearchList">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_remen"></use>
# </svg>
# <a :href="'http://irm.cninfo.com.cn/ircs/search?keyword='+ encodeURIComponent(item.shortname.replace(/%/g,'%25'))">{{handleShortName(item.shortname)}}</a>
# </div>
# </div>
# </div>
# <div class="history-list" v-show="showKeyboardBox">
# <div class="history-item" v-for="item in topKeyboardList">
# <a>
# <div class="el-col-12">
#                                                 {{item.shortName}}
#                                             </div>
# <div class="el-col-12">
#                                                 {{item.stockCode}}
#                                             </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="el-col-8 text-right" id="step2" v-cloak="">
# <div class="to-en">
# <a v-if="!isEn">English</a>
# <a v-else="">中文</a>
# </div>
# <a class="register-btn">
#                         注册</a>
# <a class="el-dropdown-link">
# <span class="change-login-btn">登录</span>
# </a>
# </div>
# </div>
# <!-- 提问弹窗 -->
# <div class="ask-question-box filter-spec-area" v-show="!isMobile">
# <el-dialog :modal-append-to-body="false" :visible.sync="questionDialogVisible" title="向上市公司提问" v-bind:close-on-click-modal="false" v-cloak="">
# <div class="form-box">
# <el-form :model="questionForm" ref="questionForm">
# <el-form-item label="" prop="companyName">
# <el-autocomplete :fetch-suggestions="queryKeyboardInfo" class="complete-box" placeholder="深市代码 / 简称 / 拼音" v-bind:disabled="disabledInput" v-model="questionForm.companyName">
# <template slot-scope="item">
# <div class="stock-code el-col-12">
#                                             {{item.item.stockCode}}
#                                         </div>
# <div class="stock-name el-col-12">
#                                             {{item.item.shortName}}
#                                         </div>
# </template>
# </el-autocomplete>
# </el-form-item>
# <el-form-item label="" prop="questionContent">
# <el-input :maxlength="200" :rows="5" placeholder="请在此输入提问！   （仅对深市公司提问）" type="textarea" v-model="questionForm.questionContent">
# </el-input>
# </el-form-item>
# </el-form>
# <div class="text-count" v-bind:class="{'red-text': questionForm.questionContent.length &gt; 200}">
#                             {{questionForm.questionContent.length}} /
#                             200字
#                         </div>
# </div>
# <div :class="{disabled: !similarityShow}" class="form-box">
# <div>
# <span style="color:#999999;">有以下相关问答，可点击查看</span>
# <a style="float: right;cursor: pointer;color: #0277E7;">收起
#                                 <i v-bind:class="[questionTip.tipIconClass]"></i>
# </a>
# </div>
# <div style="padding: 8px 0;" v-bind:class="[questionTip.tipClass]">
# <div style="cursor: pointer;" v-for="item in questionTip.tipData">
# <div style="float: left;overflow: hidden;white-space: nowrap;text-overflow: ellipsis;width:383px;padding-top:10px;color: #3F454B;">
#                                     {{item.content}}
#                                 </div>
# <div style="float: left;padding-left: 8px;padding-top:10px;color: #E29825;"><span style="background-color: #FFFAEA;">{{item.replyState}}</span></div>
# <div style="float: left;padding-left: 42px;padding-top:10px;color: #999999;">{{item.createDate}}</div>
# </div>
# </div>
# </div>
# <div class="warn-flag" v-if="isEn" v-show="specAreaWarnFlag">
#                         *System Tip：your comments may involve HongKong,Macao and Taiwan.Please do not state HongKong,Macao and Taiwan area in parallel with other countries or classify it as overseas or foreign to ensure the content is legal and compliant.
#                     </div>
# <div class="warn-flag" v-else="" v-show="specAreaWarnFlag">
#                         *系统提示：您的言论可能涉及港澳台，请勿将港澳台地区与其它国家并列表述或归为海外、国外，确保内容合法合规。
#                     </div>
# <div class="dialog-footer" slot="footer" style="padding-top: 20px;">
# <div class="right-box">
# <div class="captcha-input-content">
# <img :src="loginCaptchaPic" class="captcha-box-question"/>
# <el-input class="captcha-input" placeholder="图形验证码" v-model="questionCaptcha"></el-input>
# </div>
# <el-button :loading="questionBtnLoading" class="submit-question-btn" type="primary">发布</el-button>
# </div>
# </div>
# </el-dialog>
# </div>
# <!-- 提问临界值时身份验证的弹窗 -->
# <div class="identity-verify-box filter-spec-area" v-show="!isMobile">
# <el-dialog :modal-append-to-body="false" :visible.sync="verifiedIdentityDialogVisible" title="身份认证" v-bind:close-on-click-modal="false" v-cloak="">
# <div class="pic-box">
# <el-input :disabled="captchaDisabled" class="captcha-input" placeholder="图形验证码" v-model="identityCaptcha"></el-input>
# <img :src="loginCaptchaPic" class="captcha-box-identity"/>
# </div>
# <div style="height: 20px"></div>
# <div class="pic-box">
# <el-input class="captcha-input" placeholder="短信验证码" v-model="smsVerifyCode"></el-input>
# <span :class="{disabled: !allowSendSmsFlag}" class="captcha-box-identity btn-dynamic-code">{{sendSmsLabel}}</span>
# </div>
# <div style="padding-top: 20px;">
# <el-button class="submit-question-btn" type="primary"> 确认
#                         </el-button>
# </div>
# </el-dialog>
# </div>
# <!-- 提问临界值时身份验证的弹窗 -->
# <!-- 登录弹窗 -->
# <iframe :src="loginFrameUrl" style="width:0px;height: 0px;" v-if="loginFrameVisible"></iframe>
# <div class="login-box" v-show="!isMobile">
# <el-dialog :modal-append-to-body="false" :visible.sync="loginDialogVisible" style="margin-top:8vh;" v-bind:close-on-click-modal="false" v-cloak="" width="25%">
# <iframe :src="loginFrameUrl" style="width:100%;height: 525px;"></iframe>
# </el-dialog>
# </div>
# <!--绑定手机弹框-->
# <div class="bind-mobile-box" v-show="!isMobile">
# <el-dialog :modal-append-to-body="false" :visible.sync="verifiedDialogVisible" center="" style="margin-top:8vh;" v-cloak="" width="25%">
# <div class="content-box">
# <div class="bind-icon">
# <span class="el-icon-warning"></span>
# </div>
# <div class="bind-mobile-tip">
#                             提问功能需要手机绑定后方可使用，请前往绑定
#                         </div>
# </div>
# <div class="dialog-footer" slot="footer">
# <el-button size="medium" type="primary">去绑定
#                         </el-button>
# <el-button size="medium">已绑定
#                         </el-button>
# </div>
# </el-dialog>
# </div>
# <div class="tools-box hidden-xs-only">
# <div class="customer-service">
# <a href="http://irm.cninfo.com.cn/interview/collect/questionCollect" style="width: 100%;height: 100%" target="_blank">
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/questionGetIcon.png" style="width: 100%;height: 100%"/>
# </a>
# </div>
# <el-tooltip :visible-arrow="false" effect="light" placement="left" popper-class="qacode">
# <div slot="content">
# <p style="text-align: center;font-size: 14px;color:#333;margin-bottom: 10px">扫描二维码</p>
# <p style="text-align: center;font-size: 14px;color:#333;opacity: 0.5;margin-top: 10px">关注微信公众号</p>
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/qr-code.png" style="height: 99px;width: 99px;"/>
# </div>
# <div class="customer-service"><i class="iconfont icon-ICON_erweima"></i></div>
# </el-tooltip>
# <el-tooltip class="item" content="意见反馈" effect="dark" placement="left">
# <a href="mailto:ssi@cninfo.com.cn">
# <div class="customer-service"><i class="iconfont icon-ICON_yijian"></i></div>
# </a>
# </el-tooltip>
# <el-tooltip content="回顶部" effect="dark" placement="left">
# <div class="go-top dsn"><i class="iconfont icon-ICON_zhiding"></i></div>
# </el-tooltip>
# </div>
# </div>
# <!-- 移动端 头部 hidden-sm-and-up-->
# <div class="dl-menuwrapper hidden-sm-and-up" id="dl-menu">
# <div class="container irm-header el-row">
# <div class="el-col-12">
# <a class="header-logo" href="http://irm.cninfo.com.cn/ircs/index">
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/irm-logo.png"/>
# <svg aria-hidden="true" class="icon xinban-icon" width="100%">
# <use xlink:href="#icon-ICON_xinban"></use>
# </svg>
# </a>
# </div>
# <div class="text-right m-header-right">
# <a class="mobile-header-icon" href="http://irm.cninfo.com.cn/ircs/search/msearch">
# <i class="iconfont icon-search"></i>
# </a>
# <a class="mobile-header-icon tiwen" href="http://irm.cninfo.com.cn/ircs/question/mquestion" v-if="isLogin &amp;&amp; isMobile">
# <i class="iconfont icon-edit-square"></i>
# </a>
# <a class="mobile-header-icon tiwen" v-else="">
# <i class="iconfont icon-edit-square"></i>
# </a>
# </div>
# </div>
# <span class="login-btn">登录</span>
# </div>
# </div>
# <div class="main-wrapper">
# <!--[if IE]>
#             <div class="pc-banner hidden-xs-only">
#                 <div class="swiper-device" style="height: 300px; ">
#                     <div class="swiper-button-prev swiper-btn">
#                         <div class="swiper-btn-box">
#                             <i class="el-icon-arrow-left"></i>
#                         </div>
#                     </div>
#                     <div class="swiper-button-next swiper-btn">
#                         <div class="swiper-btn-box">
#                             <i class="el-icon-arrow-right"></i>
#                         </div>
#                     </div>
#                     <div class="swiper-container">
#                         <div class="swiper-wrapper" style="width: 1903px;height: 300px;">
#                                             <a class="swiper-slide" href="http://irm.cninfo.com.cn/interview/collect/questionCollect" target="_blank" style="width: 1903px;height: 300px;">
#                                                 <img class="imgbg mainBannerImg" src="http://resstatic.cninfo.com.cn/irm/compress_banner/banner/1660270039161.jpg"
#                                                      data-src="http://resstatic.cninfo.com.cn/irm//banner/1660270039161.jpg" alt="" style="width: 1903px;height: 300px;">
#                                             </a>
#                                                 <a class="swiper-slide" style="width: 1903px;height: 300px;">
#                                                     <img class="imgbg mainBannerImg" src="http://resstatic.cninfo.com.cn/irm/compress_banner/banner/1606728041952.png"
#                                                          data-src="http://resstatic.cninfo.com.cn/irm//banner/1606728041952.png" alt="" style="width: 1903px;height: 300px;">
#                                                 </a>
#                                                 <a class="swiper-slide" style="width: 1903px;height: 300px;">
#                                                     <img class="imgbg mainBannerImg" src="http://resstatic.cninfo.com.cn/irm/compress_banner/banner/1606444595291.png"
#                                                          data-src="http://resstatic.cninfo.com.cn/irm//banner/1606444595291.png" alt="" style="width: 1903px;height: 300px;">
#                                                 </a>
#                         </div>
#                     </div>
#                     <div class="pagination">
#                         <span class="swiper-pagination-switch"></span>
#                         <span class="swiper-pagination-switch"></span>
#                         <span class="swiper-pagination-switch"></span>
#                         <span class="swiper-pagination-switch swiper-visible-switch swiper-active-switch"></span>
#                     </div>
#                 </div>
#             </div>
#         <![endif]-->
# <!--[if !IE]><!-->
# <!-- pc 顶部轮播-->
# <div class="swiper-container hidden-xs-only" id="pc-swiper" style="height: 300px; ">
# <div class="swiper-wrapper">
# <a class="swiper-slide no-ie mainBannerImgNoIE" href="http://irm.cninfo.com.cn/interview/collect/questionCollect" style="background-image: url('http://resstatic.cninfo.com.cn/irm//banner/1660270039161.jpg')" target="_blank"></a>
# <a class="swiper-slide no-ie mainBannerImgNoIE" data-src="background-image: url('http://resstatic.cninfo.com.cn/irm//banner/1606728041952.png')" style="background-image: url('http://resstatic.cninfo.com.cn/irm/compress_banner/banner/1606728041952.png')"></a>
# <a class="swiper-slide no-ie mainBannerImgNoIE" data-src="background-image: url('http://resstatic.cninfo.com.cn/irm//banner/1606444595291.png')" style="background-image: url('http://resstatic.cninfo.com.cn/irm/compress_banner/banner/1606444595291.png')"></a>
# </div>
# <!-- 如果需要导航按钮 -->
# <div class="swiper-button-prev swiper-btn">
# <div class="swiper-btn-box">
# <i class="el-icon-arrow-left"></i>
# </div>
# </div>
# <div class="swiper-button-next swiper-btn">
# <div class="swiper-btn-box">
# <i class="el-icon-arrow-right"></i>
# </div>
# </div>
# <!-- 如果需要分页器 -->
# <div class="swiper-pagination"></div>
# </div>
# <!--<![endif]-->
# <!-- 移动端 顶部轮播-->
# <div class="swiper-container hidden-sm-and-up" id="mobile-swiper" style="height: 140px;">
# <div class="swiper-wrapper">
# <a class="swiper-slide mainBannerImgNoIE" data-src="background-image: url('http://resstatic.cninfo.com.cn/irm//banner/1563965997984.png')" href="javascript:void(0)" style="background-image: url('http://resstatic.cninfo.com.cn/irm/compress_banner/banner/1563965997984.png')" target="_blank"></a>
# <a class="swiper-slide mainBannerImgNoIE" data-src="background-image: url('http://resstatic.cninfo.com.cn/irm//banner/1563965984962.png')" href="javascript:void(0)" style="background-image: url('http://resstatic.cninfo.com.cn/irm/compress_banner/banner/1563965984962.png')" target="_blank"></a>
# <a class="swiper-slide mainBannerImgNoIE" data-src="background-image: url('http://resstatic.cninfo.com.cn/irm//banner/1563965953663.png')" href="javascript:void(0)" style="background-image: url('http://resstatic.cninfo.com.cn/irm/compress_banner/banner/1563965953663.png')" target="_blank"></a>
# </div>
# <!-- 如果需要分页器 -->
# <div class="swiper-pagination"></div>
# </div>
# <!-- 提示信息 -->
# <div id="tips-app">
# </div>
# <div class="mobile-content hidden-sm-and-up">
# <div class="swiper-container mobile-tabs" id="mobile-tabs">
# <div class="swiper-wrapper">
# <div class="swiper-slide" data-status="0">全部</div>
# <div class="swiper-slide active" data-status="1">问答</div>
# <div class="swiper-slide" data-status="3">公告</div>
# <div class="swiper-slide" data-status="2">声音</div>
# <div class="swiper-slide" data-status="4">投资者关系</div>
# </div>
# </div>
# </div>
# <!-- 预加载内容 -->
# <div class="content-wrapper" id="preApp">
# <div class="mobile-container container el-row">
# <div class="el-col-17 el-col-xs-24 sub-wrapper">
# <div class="left-content hidden-xs-only" style="position: relative">
# <div class="index-first-tab">
# <div class="top-tab el-tabs el-tabs--top">
# <div class="el-tabs__header is-top">
# <div class="el-tabs__nav-wrap is-top">
# <div class="el-tabs__nav-scroll">
# <div class="el-tabs__nav is-top" role="tablist" style="transform: translateX(0px);">
# <div class="el-tabs__active-bar is-top" style="width: 56px; transform: translateX(0px);"></div>
# <div aria-controls="pane-1" aria-selected="true" class="el-tabs__item is-top is-active" id="tab-1" role="tab" tabindex="0">
# <span>问答</span>
# </div>
# <div aria-controls="pane-2" class="el-tabs__item is-top" id="tab-2" role="tab" tabindex="-1">
# <span>资讯</span>
# </div>
# <div aria-controls="pane-3" class="el-tabs__item is-top" id="tab-3" role="tab" tabindex="-1">
# <span>云访谈</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="el-tabs__content">
# <div aria-labelledby="tab-1" class="el-tab-pane" id="pane-1" role="tabpanel"></div>
# <div aria-hidden="true" aria-labelledby="tab-2" class="el-tab-pane" id="pane-2" role="tabpanel" style="display: none;">
# <div class="my-tabs-box">
# <div class="sub-tab active">关注动态</div>
# <div class="sub-tab">
# <div class="el-dropdown">
# <span aria-controls="dropdown-menu-6227" aria-haspopup="list" class="el-dropdown-link el-dropdown-selfdefine" role="button" tabindex="0">
#                   提问
#                   <i class="el-icon-caret-bottom el-icon--right"></i>
# </span>
# <ul class="el-dropdown-menu el-popper el-dropdown-menu--small" id="dropdown-menu-6227" style="display: none;">
# <li class="el-dropdown-menu__item active-dropdown" tabindex="-1">全部</li>
# <li class="el-dropdown-menu__item" tabindex="-1">已回复</li>
# <li class="el-dropdown-menu__item" tabindex="-1"> 未回复</li>
# </ul>
# </div>
# </div>
# <div class="sub-tab">收藏
#                                             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div class="select-box pd-20 pb-20">
# <div class="sub-tab">
# <label class="el-checkbox" role="checkbox">
# <span aria-checked="mixed" class="el-checkbox__input">
# <span class="el-checkbox__inner"></span>
# <input aria-hidden="true" class="el-checkbox__original" type="checkbox" value="公司公告"/>
# </span>
# <span class="el-checkbox__label">只看已回复</span>
# </label>
# </div>
# <div class="sub-tab-all">
#                                    全部
#                                 </div>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>*</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">*ST计通
#                                         <span class="company-code hidden-sm-and-up">(300330)</span>
# </span>
# <span class="company-code hidden-xs-only">[300330]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             您好，请问截止8月10日股东户数是多少，谢谢！
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" href="http://irm.cninfo.com.cn/ircs/investorHomePage/investorInfo?userId=937780811820232704" target="_blank">
# <span class="user-name hidden-xs-only">默默向上游巛灬 ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              App</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 1 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>*</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">*ST计通
#                                         <span class="company-code hidden-sm-and-up">(300330)</span>
# </span>
# <span class="company-code hidden-xs-only">[300330]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             请问：截止8月10日，股东总人数是多少户？
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" href="http://irm.cninfo.com.cn/ircs/investorHomePage/investorInfo?userId=1167747482723991552" target="_blank">
# <span class="user-name hidden-xs-only">irm40324903 ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              网站</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 1 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>*</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">*ST计通
#                                         <span class="company-code hidden-sm-and-up">(300330)</span>
# </span>
# <span class="company-code hidden-xs-only">[300330]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             公司退市流程大概需要多久 提前发公告吗
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" href="http://irm.cninfo.com.cn/ircs/investorHomePage/investorInfo?userId=893458931192344576" target="_blank">
# <span class="user-name hidden-xs-only">irm16580914 ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              App</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 1 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>*</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">*ST计通
#                                         <span class="company-code hidden-sm-and-up">(300330)</span>
# </span>
# <span class="company-code hidden-xs-only">[300330]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             按照退市新规后 收到行政处罚告知书 的情况， 贵司2020年度~至今的年度报表才是是否退市关键吧？ 为何董秘没有详细回复风险情况呢？
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" style="pointer-events: none" target="_blank">
# <span class="user-name hidden-xs-only">cninfo690254 ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              网站</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 点赞 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>*</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">*ST计通
#                                         <span class="company-code hidden-sm-and-up">(300330)</span>
# </span>
# <span class="company-code hidden-xs-only">[300330]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             董秘您好！从8月5日公司一而再修改公告内容看，公司法务专业性值得推敲，管中窥豹，在如此美好的大背景下结合公司业绩，也难免让投资者对公司管理产生忧虑。从目前公告看，公司处境实在堪忧，投资者因为此处罚将产生巨大的损失，希望公司内部尽职核查，做好申诉！另问公司及集团对投资者损失的后续赔偿事项有没有提上日程？辛苦！谢谢！
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" href="http://irm.cninfo.com.cn/ircs/investorHomePage/investorInfo?userId=589020551056293888" target="_blank">
# <span class="user-name hidden-xs-only">irm3820069 ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              网站</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 点赞 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>*</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">*ST计通
#                                         <span class="company-code hidden-sm-and-up">(300330)</span>
# </span>
# <span class="company-code hidden-xs-only">[300330]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             董秘，您好！请问全资子公司上海翊客湾科技有限公司是在围绕着华为公司技术打造生态圈吗？谢谢！
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" style="pointer-events: none" target="_blank">
# <span class="user-name hidden-xs-only">cninfo839452 ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              网站</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 点赞 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>*</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">*ST计通
#                                         <span class="company-code hidden-sm-and-up">(300330)</span>
# </span>
# <span class="company-code hidden-xs-only">[300330]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             尊敬的董秘 您好！  请问8月10日股东人数是多少？谢谢
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" href="http://irm.cninfo.com.cn/ircs/investorHomePage/investorInfo?userId=662525574842249216" target="_blank">
# <span class="user-name hidden-xs-only">irm5443341 ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              网站</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 点赞 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>长</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">长城证券
#                                         <span class="company-code hidden-sm-and-up">(002939)</span>
# </span>
# <span class="company-code hidden-xs-only">[002939]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             请问董秘，目前截止8月11股东人数多少
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" style="pointer-events: none" target="_blank">
# <span class="user-name hidden-xs-only">cninfo666629 ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              网站</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 点赞 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>长</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">长城证券
#                                         <span class="company-code hidden-sm-and-up">(002939)</span>
# </span>
# <span class="company-code hidden-xs-only">[002939]</span>
# <span class="question-time hidden-sm-and-up">1小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">1小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             您好！请问截止8月10日收盘公司股东人数是多少，谢谢!
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" href="http://irm.cninfo.com.cn/ircs/investorHomePage/investorInfo?userId=89132281620332544" target="_blank">
# <span class="user-name hidden-xs-only">zugang ·</span>
# </a>
# <span class="question-time hidden-xs-only">1小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              App</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 点赞 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>善</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">善水科技
#                                         <span class="company-code hidden-sm-and-up">(301190)</span>
# </span>
# <span class="company-code hidden-xs-only">[301190]</span>
# <span class="question-time hidden-sm-and-up">2小时前</span>
# </span>
# <button class="el-button like-box hidden-xs-only el-button--primary el-button--mini" type="button">
# <span>
# <i class="el-icon-plus"></i>
# <span class="attention-text">关注</span>
# </span>
# </button>
# <div class="right-box hidden-xs-only hidden-sm-and-up">
# <span class="question-time">2小时前</span>
# </div>
# </div>
# <div class="table-content translate-box pd-20" style="overflow: inherit;">
# <a>
# <div class="question-content" style="font-weight: normal;">
# <img alt="" class="question-icon" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/question-icon.png"/>
#                                             公司有水利工程订单有吗！
#                                         </div>
# </a>
# </div>
# <div class="table-footer pd-10-20">
# <span class="flag-title hidden-xs-only new-question-icon">
# <svg aria-hidden="true" class="icon" width="100%">
# <use xlink:href="#icon-ICON_NEW"></use>
# </svg>
#                                                 最新 · 问答</span>
# <a class="hidden-xs-only" href="http://irm.cninfo.com.cn/ircs/investorHomePage/investorInfo?userId=1125661647946563584" target="_blank">
# <span class="user-name hidden-xs-only">irm36800912 ·</span>
# </a>
# <span class="question-time hidden-xs-only">2小时前 ·</span>
# <span class="question-platform hidden-xs-only">来源
#                                              App</span>
# <div class="right-box el-row">
# <span class="like-content el-col-xs-8" data-status="0"><i class="iconfont icon-ICON_dianzan"></i>
# <span class="count-number"> 点赞 </span></span>
# <span class="like-content el-col-xs-8 shareClick"><i class="iconfont icon-ICON_fenxiang"></i>分享</span>
# <span class="like-content el-col-xs-8 collection" data-status="0"><i class="iconfont icon-ICON_shoucang"></i>
# 收藏                                        </span>
# </div>
# </div>
# <div class="el-loading-mask cover"><div class="el-loading-spinner"></div></div>
# </div>
# <div class="left-content table-list" style="position: relative;">
# <div class="table-head pd-20">
# <div class="common-head">
# <span>善</span>
# </div>
# <span class="company-name m-company-name">
# <span class="compnay-name">善水科技
#                                         <span class="company-code hidden-sm-and-up">(301190)</span>
# </span>
# <span class="company-code hidden-xs-only">[301190]</span>
# ...
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=002534&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">西子洁能</div>
# <div class="company-code">[002534]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=002549&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">凯美特气</div>
# <div class="company-code">[002549]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=002667&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">鞍重股份</div>
# <div class="company-code">[002667]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=002850&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">科达利</div>
# <div class="company-code">[002850]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=002895&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">川恒股份</div>
# <div class="company-code">[002895]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=002952&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">亚世光电</div>
# <div class="company-code">[002952]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=002959&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">小熊电器</div>
# <div class="company-code">[002959]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=003042&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">中农联合</div>
# <div class="company-code">[003042]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=300045&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">华力创通</div>
# <div class="company-code">[300045]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=300092&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">科新机电</div>
# <div class="company-code">[300092]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=300271&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">华宇软件</div>
# <div class="company-code">[300271]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=300306&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">远方信息</div>
# <div class="company-code">[300306]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=300335&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">迪森股份</div>
# <div class="company-code">[300335]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=300476&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">胜宏科技</div>
# <div class="company-code">[300476]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=300712&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">永福股份</div>
# <div class="company-code">[300712]</div>
# </div>
# </div>
# </a>
# </div>
# <div class="sub-item el-col-8">
# <a href="http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode=300721&amp;orgId=" target="_blank">
# <div class="company-box">
# <div class="company-content">
# <div class="company-name">怡达股份</div>
# <div class="company-code">[300721]</div>
# </div>
# </div>
# </a>
# </div>
# </div>
# <div class="sub-footer">
# <a href="http://wltp.cninfo.com.cn/gddh_vote/vote/index.do" target="_blank">
# <div class="more">更多 <i class="el-icon-arrow-right"></i></div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="mobile-container container el-row special-tips-message" v-show="indexNoticeFlag &amp;&amp; tabIsZongHe &amp;&amp; closeNoticeTip">
# <div class="el-col-17 el-col-xs-24">
# <div class="left-content">
# <span>有更新↑
#                             <i class="el-icon-circle-close"></i>
# </span>
# </div>
# </div>
# <div class="el-col-7">
# <div class="week-statistics"></div>
# </div>
# </div>
# <div>
# </div>
# <!-- 已员 弹窗 -->
# <el-dialog :modal-append-to-body="true" :visible.sync="followerDialogVisible" title="已关注" v-cloak="" width="900px">
# <div class="dialog-people-list">
# <div class="dialog-people-item el-col-12" v-for="item in followerList">
# <div style="border: 1px solid #eee;padding: 20px;">
# <a :href="'http://irm.cninfo.com.cn/ircs'+ '/investorHomePage/investorInfo?userId=' + item.userId" target="_blank">
# <img :src="item.imageUrl | handlePeopleNoImg" class="" item.username="" v-if="item.imageUrl != undefined"/>
# </a>
# <div class="sub-content">
# <a :href="'http://irm.cninfo.com.cn/ircs'+ '/investorHomePage/investorInfo?userId=' + item.userId" target="_blank">
# <div class="sub-name">{{item.userName ? item.userName : '-'}}</div>
# </a>
# <div><span>提问数
#                                     ：{{item.questionCount}}</span><span>被关注数
#                                     ：{{item.fansCount}}</span></div>
# </div>
# <el-button class="right-content active" data-status="1" item.userid="">
# <span class="attention-text">已关注</span>
# </el-button>
# </div>
# </div>
# </div>
# </el-dialog>
# <!-- 粉丝 弹窗 -->
# <el-dialog :modal-append-to-body="true" :visible.sync="fansDialogVisible" title="粉丝" v-cloak="" width="900px">
# <div class="dialog-people-list">
# <div class="dialog-people-item el-col-12" v-for="item in fansList">
# <div style="border: 1px solid #eee;padding: 20px;">
# <a :href="'http://irm.cninfo.com.cn/ircs'+ '/investorHomePage/investorInfo?userId=' + item.userId">
# <img :src="item.imageUrl | handlePeopleNoImg" class="" item.username="" v-if="item.imageUrl != undefined"/>
# </a>
# <div class="sub-content">
# <a :href="'http://irm.cninfo.com.cn/ircs'+ '/investorHomePage/investorInfo?userId=' + item.userId">
# <div class="sub-name">{{item.userName ? item.userName : '-'}}</div>
# </a>
# <div><span>提问数
#                                     ：{{item.questionCount}}</span><span>被关注数
#                                     ：{{item.fansCount}}</span></div>
# </div>
# <el-button :class="{active: item.attentionStatus}" :data-status="item.attentionStatus ? '1':'0'" class="right-content" item.userid="">
# <span class="attention-text">{{item.attentionStatus ? '已关注': '关注'}}<span>
# </span></span></el-button>
# </div>
# </div>
# </div>
# <el-pagination :current-page="fansPageNo" :total="fansCount" background="" layout="prev,pager,next" style="margin: 10px 0">
# </el-pagination>
# </el-dialog>
# <!-- 已关注公司列表 -->
# <div class="attention-company-list">
# <el-dialog :visible.sync="careCompanyDialogVisible" title="已关注公司列表" v-bind:close-on-click-modal="false" v-cloak="">
# <div class="dialog-people-list el-col-14">
# <div class="search-input">
# <span>
# <el-select placeholder="所属行业" size="small" style="width:232px" v-model="industry">
# <el-option :key="item.name" :label="item.name" :value="item.value" v-for="item in industryOptions">
# </el-option></el-select>
# </span>
# <el-autocomplete :fetch-suggestions="queryKeyboardInfo" class="sub-input" false="" placeholder="输入代码/简称/拼音/关键词并回车" size="small" true="" v-model="careCompanyInputValue" width="400">
# <template slot-scope="item">
# <div class="stock-code el-col-12">{{item.item.stockCode}}</div>
# <div class="stock-name el-col-12">{{item.item.shortName}}</div>
# </template>
# </el-autocomplete>
# </div>
# <div class="scroll-content">
# <p class="tips">提示：点击公司行即可添加至已关注公司列表</p>
# <div class="search-result">
# <div class="title row-list">
# <span>公司代码</span>
# <span>公司简称</span>
# <span>所属行业</span>
# </div>
# <div class="search-result-list" v-if="searchCompanyDataList.length &gt; 0">
# <div :class="{'active':item.attention == true}" class="row-list" v-for="item in searchCompanyDataList">
# <span>{{item.stockCode}}</span>
# <span>{{item.shortName}}</span>
# <span>{{item.trade}}</span>
# </div>
# </div>
# <p style="text-align: center" v-if="searchCompanyDataList.length == 0">暂无内容，请稍后回来</p>
# </div>
# </div>
# <div class="search-num">
# <span class="total-num">查询结果：共
#                                 <span>{{totalSeachNum}}</span>家</span>
# <span class="allow-num" v-if="careCompanyCount &lt;=50">剩余可关注数：{{50-careCompanyCount}}家</span>
# <span class="allow-num" style="color:red;" v-else="">抱歉，您关注的公司已经超过50家</span>
# <span class="attention">一键关注</span>
# </div>
# </div>
# <div class="dialog-company-list el-col-10">
# <div class="main-title">共
#                             {{careCompanyCount}}家关注公司</div>
# <div class="dialog-company-item el-col-12" v-for="item in careCompanyList">
# <div class="my-company-box">
# <a :href="'http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode='+ item.stockCode + '&amp;orgId=' +item.orgId" target="_blank">
# <div class="sub-name">{{item.shortName}}</div>
# </a>
# <span class="el-icon-close" item=""></span>
# <a :href="'http://irm.cninfo.com.cn/ircs/company/companyDetail?stockcode='+ item.stockCode + '&amp;orgId=' +item.orgId" target="_blank">
# <div class="sub-content">
# <div><span>[{{item.stockCode}}]</span></div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </el-dialog>
# </div>
# <!-- 用户搜索弹窗 -->
# <div class="search-user-dialog">
# <el-dialog :modal-append-to-body="true" :visible.sync="searchUserDialogVisible" title="搜索新用户">
# <div class="search-user-input" style="margin-bottom: 20px">
# <el-input placeholder="输入用户名，按回车键搜索用户" v-model="searchUserInput">
# </el-input>
# </div>
# <div class="dialog-people-list dialog-people-list-search">
# <div class="dialog-people-item el-col-24" id="search-investor" v-for="item in searchUserList" v-if="searchUserList.length &gt; 0">
# <a :href="'http://irm.cninfo.com.cn/ircs'+ '/investorHomePage/investorInfo?userId=' + item.userId" target="_blank">
# <div style="border: 1px solid #eee;padding: 20px;">
# <img :src="item.imageUrl | handlePeopleNoImg" onerror="javascript: this.src = 'http://ircsstatic.cninfo.com.cn/ircs//assets/images/icon-avatar.png'" v-if="item.imageUrl != undefined"/>
# <div class="sub-content">
# <div class="sub-name">{{item.userName ? item.userName : '-'}}</div>
# <div><span>提问数
#                                             ：{{item.questionCount}}</span><span>被关注数
#                                             ：{{item.fansCount}}</span></div>
# </div>
# </div>
# </a>
# </div>
# <div v-if="searchUserList.length == 0 &amp;&amp; searchUserListFlag">未匹配到相关用户！</div>
# </div>
# </el-dialog>
# </div>
# <!-- 编辑栏目 弹窗-->
# <div class="create-column">
# <el-dialog :modal-append-to-body="true" :visible.sync="editQuickSectionDialogVisible" title="编辑定制搜索内容" v-cloak="" width="30%">
# <el-input :maxlength="6" placeholder="请输入定制搜索内容" v-model="editQuickSectionInput"></el-input>
# <div class="calculation">
# <span>{{editQuickSectionInput.length&gt; 6 ? 6 : editQuickSectionInput.length}}</span>/6
#                     </div>
# <div class="dialog-footer" slot="footer">
# <el-button false="">取消</el-button>
# <el-button type="primary">确定</el-button>
# </div>
# </el-dialog>
# </div>
# <!-- 新增栏目 弹窗-->
# <div class="create-column">
# <el-dialog :modal-append-to-body="true" :visible.sync="addQuickSectionDialogVisible" title="创建定制搜索" v-cloak="" width="30%">
# <el-input :maxlength="6" placeholder="请输入定制搜索内容" v-model="addQuickSectionInput"></el-input>
# <div class="calculation">
# <span>{{addQuickSectionInput.length&gt;6 ? 6 : addQuickSectionInput.length}}</span>/6
#                     </div>
# <div class="dialog-footer" slot="footer">
# <el-button false="">取消</el-button>
# <el-button type="primary">创建</el-button>
# </div>
# </el-dialog>
# </div>
# <div class="strip hidden-xs-only">
# <div class="ask-question-main">
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/strip-btn.png"/>
# <i class="el-icon-close"></i>
# </div>
# </div>
# </div>
# <div class="voice-bigimg" id="outdiv">
# <div class="img-indiv">
# <img class="img-result" id="bigimg" src=""/>
# </div>
# </div>
# </div>
# </div>
# <!-- 引入 iconfont -->
# <script src="http://ircsstatic.cninfo.com.cn/ircs//assets/iconfont/iconfont.js"></script>
# <script src="http://ircsstatic.cninfo.com.cn/ircs//scripts/lib/placeholder.js"></script>
# <div class="footer hidden-xs-only">
# <div class="footer-top container el-row">
# <div class="el-col-10 link-box">
# <div class="sub-title">相关链接</div>
# <div class="sub-content el-row" style="height: 159px;">
# <div class="el-col-8"><a class="link" href="http://www.szse.cn/" target="_blank"><img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/shenjiaosuo.png"/></a></div>
# <div class="el-col-8"><a class="link" href="http://www.szse.cn/investor/" target="_blank"><img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/toujiao.png"/></a></div>
# <div class="el-col-8"><a class="link" href="http://www.cninfo.com.cn/" target="_blank"><img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/juchao.png"/></a></div>
# </div>
# </div>
# <div class="el-col-8 qrcode-box">
# <div class="sub-title">其他服务</div>
# <div class="el-col-10" style="margin-left: 27px;">
# <a class="link"><img alt="" class="qrcode-img" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/qr-code.png"/></a>
# <div class="sub-name">互动易公众号</div>
# </div>
# <div class="el-col-10" style="border-right: 1px solid #eee">
# <a class="link"><img alt="" class="qrcode-img investor-qrcode" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/app-qr-code.png"/></a>
# <div class="sub-name">互动易APP</div>
# </div>
# </div>
# <div class="el-col-6 call-box">
# <p class="tel-content">配号、中签查询 400-808-9999</p>
# <p class="tel-content">短信服务 0755-82083000</p>
# <p class="tel-content">微信服务 szse1990</p>
# <p class="tel-content">工作建议与投诉 cis@szse.cn</p>
# </div>
# </div>
# <div class="footer-content container el-row">
# <p>免责声明：本网站仅作为投资者与上市公司互动交流的平台，深圳证券交易所力求本平台信息准确可靠，但并不对其准确性、完整性和及时性做出任何保证，若使用本网站信息造成用户损失或引致其他法律纠纷，深圳证券交易所不承担任何责任。本网站任何信息均不构成投资建议，投资者据此操作，风险自担。
#         </p>
# </div>
# <div class="footer-bottom el-row">
# <hr class="line"/>
# <p><span>深圳证券交易所 版权所有 2018 Shenzhen Stock Exchange. ALl Rights Reserved</span></p>
# <p class="record-info">
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/record.png"/>
# <span>[粤ICP备05012689
#                     <a href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=44030402002031" target="_blank">
# (粤公网安备44030402002031号)                    </a>
#                         ]
#                 </span>
# </p>
# </div>
# </div>
# <div class="mask">
# <ul>
# <li class="step-1" style="margin-left: 27px">
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/guide1.png"/>
# <input class="next-step" type="button" value=""/>
# <input class="close" type="button" value=""/>
# </li>
# <li>
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/guide2.png"/>
# <input class="next-step" type="button" value=""/>
# <input class="close" type="button" value=""/>
# </li>
# <li style="margin-left: 1px">
# <img alt="" src="http://ircsstatic.cninfo.com.cn/ircs//assets/images/guide3.png"/>
# <input class="last-close" type="button" value=""/>
# </li>
# </ul>
# </div>
# </body>
# </html>
